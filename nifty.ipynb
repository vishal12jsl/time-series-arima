# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df=pd.read_csv("NIFTY50_all.csv",index_col=0,parse_dates=True)

# %%
df
# Out:
#                 Symbol Series  Prev Close    Open     High     Low    Last  \
# Date
# 2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.00  959.00
# 2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.00  885.00
# 2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.00  887.00
# 2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.00  929.00
# 2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.00  980.00
# ...                ...    ...         ...     ...      ...     ...     ...
# 2020-06-24        ZEEL     EQ      181.95  184.90   185.35  172.50  174.00
# 2020-06-25        ZEEL     EQ      174.10  172.00   176.40  168.80  172.75
# 2020-06-26        ZEEL     EQ      172.35  175.50   180.75  174.15  176.60
# 2020-06-29        ZEEL     EQ      176.25  174.90   175.10  167.80  172.05
# 2020-06-30        ZEEL     EQ      172.05  174.00   175.80  169.60  171.30
#
#              Close    VWAP    Volume      Turnover    Trades  \
# Date
# 2007-11-27  962.90  984.72  27294366  2.687719e+15       NaN
# 2007-11-28  893.90  941.38   4581338  4.312765e+14       NaN
# 2007-11-29  884.20  888.09   5124121  4.550658e+14       NaN
# 2007-11-30  921.55  929.17   4609762  4.283257e+14       NaN
# 2007-12-03  969.30  965.65   2977470  2.875200e+14       NaN
# ...            ...     ...       ...           ...       ...
# 2020-06-24  174.10  180.05  21628059  3.894106e+14  126608.0
# 2020-06-25  172.35  173.63  17818871  3.093893e+14  110808.0
# 2020-06-26  176.25  177.39  17933761  3.181294e+14  103078.0
# 2020-06-29  172.05  170.93  14624428  2.499745e+14   95422.0
# 2020-06-30  171.10  172.95  10280629  1.777998e+14   67886.0
#
#             Deliverable Volume  %Deliverble
# Date
# 2007-11-27           9859619.0       0.3612
# 2007-11-28           1453278.0       0.3172
# 2007-11-29           1069678.0       0.2088
# 2007-11-30           1260913.0       0.2735
# 2007-12-03            816123.0       0.2741
# ...                        ...          ...
# 2020-06-24           3799934.0       0.1757
# 2020-06-25           3101417.0       0.1741
# 2020-06-26           2425494.0       0.1352
# 2020-06-29           2485891.0       0.1700
# 2020-06-30           1731100.0       0.1684
#
# [226804 rows x 14 columns]

# %%
nf=df[(df['Symbol']=="ONGC")]

# %%
nf
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2000-01-03   ONGC     EQ      207.70  205.00  214.40  205.00  214.00  213.45
# 2000-01-04   ONGC     EQ      213.45  201.50  209.70  201.00  209.00  206.55
# 2000-01-05   ONGC     EQ      206.55  201.00  223.10  200.50  223.10  223.10
# 2000-01-06   ONGC     EQ      223.10  234.00  234.90  217.60  217.60  219.30
# 2000-01-07   ONGC     EQ      219.30  223.00  223.00  213.00  215.70  215.75
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2020-06-24   ONGC     EQ       85.65   86.25   86.65   82.55   82.70   83.10
# 2020-06-25   ONGC     EQ       83.10   82.25   84.00   80.00   82.90   81.60
# 2020-06-26   ONGC     EQ       81.60   83.10   84.80   82.50   83.95   84.15
# 2020-06-29   ONGC     EQ       84.15   83.95   84.10   81.60   82.40   82.40
# 2020-06-30   ONGC     EQ       82.40   83.50   83.55   80.65   81.50   81.35
#
#               VWAP     Volume      Turnover    Trades  Deliverable Volume  \
# Date
# 2000-01-03  209.91       9600  2.015090e+11       NaN                 NaN
# 2000-01-04  206.26      17900  3.692030e+11       NaN                 NaN
# 2000-01-05  215.46      27000  5.817490e+11       NaN                 NaN
# 2000-01-06  223.42      35600  7.953680e+11       NaN                 NaN
# 2000-01-07  215.19      11400  2.453145e+11       NaN                 NaN
# ...            ...        ...           ...       ...                 ...
# 2020-06-24   84.64   33082696  2.799961e+14  100069.0          12549657.0
# 2020-06-25   81.82  121278403  9.922713e+14  144246.0          61537386.0
# 2020-06-26   83.82   23684918  1.985216e+14   72958.0           7687592.0
# 2020-06-29   82.53   14299404  1.180114e+14   52413.0           5848656.0
# 2020-06-30   82.19   25762628  2.117556e+14   77411.0           9702702.0
#
#             %Deliverble
# Date
# 2000-01-03          NaN
# 2000-01-04          NaN
# 2000-01-05          NaN
# 2000-01-06          NaN
# 2000-01-07          NaN
# ...                 ...
# 2020-06-24       0.3793
# 2020-06-25       0.5074
# 2020-06-26       0.3246
# 2020-06-29       0.4090
# 2020-06-30       0.3766
#
# [5097 rows x 14 columns]

# %%
nf.columns
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
nf1=nf[['High','Low']]

# %%
nf1
# Out:
#               High     Low
# Date
# 2000-01-03  214.40  205.00
# 2000-01-04  209.70  201.00
# 2000-01-05  223.10  200.50
# 2000-01-06  234.90  217.60
# 2000-01-07  223.00  213.00
# ...            ...     ...
# 2020-06-24   86.65   82.55
# 2020-06-25   84.00   80.00
# 2020-06-26   84.80   82.50
# 2020-06-29   84.10   81.60
# 2020-06-30   83.55   80.65
#
# [5097 rows x 2 columns]

# %%
nf1['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
nf1
# Out:
#               High     Low
# Date
# 2000-01-03  214.40  205.00
# 2000-01-04  209.70  201.00
# 2000-01-05  223.10  200.50
# 2000-01-06  234.90  217.60
# 2000-01-07  223.00  213.00
# ...            ...     ...
# 2020-06-24   86.65   82.55
# 2020-06-25   84.00   80.00
# 2020-06-26   84.80   82.50
# 2020-06-29   84.10   81.60
# 2020-06-30   83.55   80.65
#
# [5097 rows x 2 columns]

# %%
nf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5097 entries, 2000-01-03 to 2020-06-30
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   High    5097 non-null   float64
#  1   Low     5097 non-null   float64
# dtypes: float64(2)
# memory usage: 119.5 KB

# %%
nf1.describe()
# Out:
#               High          Low
# count  5097.000000  5097.000000
# mean    517.024328   499.011978
# std     391.300986   377.118655
# min      63.000000    50.000000
# 25%     192.950000   188.000000
# 50%     322.000000   311.700000
# 75%     870.000000   840.100000
# max    1513.900000  1443.150000

# %%
nf1['diff']=nf1['Low']-nf1['Low'].shift(1)
# Out:
# C:\Users\VAIBHAV\AppData\Local\Temp\ipykernel_8824\1946126151.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nf1['diff']=nf1['Low']-nf1['Low'].shift(1)

# %%
nf1
# Out:
#               High     Low   diff
# Date
# 2000-01-03  214.40  205.00    NaN
# 2000-01-04  209.70  201.00  -4.00
# 2000-01-05  223.10  200.50  -0.50
# 2000-01-06  234.90  217.60  17.10
# 2000-01-07  223.00  213.00  -4.60
# ...            ...     ...    ...
# 2020-06-24   86.65   82.55  -1.85
# 2020-06-25   84.00   80.00  -2.55
# 2020-06-26   84.80   82.50   2.50
# 2020-06-29   84.10   81.60  -0.90
# 2020-06-30   83.55   80.65  -0.95
#
# [5097 rows x 3 columns]

# %%
nf1['diff'].dropna().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
nf1['diff2']=nf1['Low']-nf1['Low'].shift(2)
# Out:
# C:\Users\VAIBHAV\AppData\Local\Temp\ipykernel_8824\2910999039.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nf1['diff2']=nf1['Low']-nf1['Low'].shift(2)

# %%
nf1
# Out:
#               High     Low   diff  diff2
# Date
# 2000-01-03  214.40  205.00    NaN    NaN
# 2000-01-04  209.70  201.00  -4.00    NaN
# 2000-01-05  223.10  200.50  -0.50  -4.50
# 2000-01-06  234.90  217.60  17.10  16.60
# 2000-01-07  223.00  213.00  -4.60  12.50
# ...            ...     ...    ...    ...
# 2020-06-24   86.65   82.55  -1.85  -1.55
# 2020-06-25   84.00   80.00  -2.55  -4.40
# 2020-06-26   84.80   82.50   2.50  -0.05
# 2020-06-29   84.10   81.60  -0.90   1.60
# 2020-06-30   83.55   80.65  -0.95  -1.85
#
# [5097 rows x 4 columns]

# %%
nf1['diff2'].dropna().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(nf1['diff'].dropna())
# Out:
# (-31.06169497695995,
#  0.0,
#  5,
#  5090,
#  {'1%': -3.431635383281896,
#   '5%': -2.862108002627225,
#   '10%': -2.5670723481073487},
#  45312.04197269398)

# %%
adfuller(nf1['diff2'].dropna())
# Out:
# (-12.086125526825276,
#  2.1755313479796427e-22,
#  33,
#  5061,
#  {'1%': -3.4316427523882655,
#   '5%': -2.8621112582803367,
#   '10%': -2.567074081214908},
#  45493.823155597194)

# %%
def adf_test(series):
    result=adfuller(series)
    print('ADF Statistics: {}'.format(result[0]))
    print('p- value: {}'.format(result[1]))
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis.indicating it is stationary")
    else:
        print("weak evidence against null hypothesis,indicating it is non-stationary ")

# %%
adf_test(nf1['diff2'].dropna())
# Out:
# ADF Statistics: -12.086125526825276
# p- value: 2.1755313479796427e-22
# strong evidence against the null hypothesis, reject the null hypothesis.indicating it is stationary

# %%
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
fig=plt.figure(figsize=(12,8))
ax1=fig.add_subplot(211)
fig=sm.graphics.tsa.plot_acf(nf1['diff2'].dropna(),lags=40,ax=ax1)
ax2=fig.add_subplot(212)
fig=sm.graphics.tsa.plot_pacf(nf1['diff2'].dropna(),lags=40,ax=ax2)

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
model=ARIMA(nf1['diff2'],order=(3,2,1))
model_fit=model.fit()
# Out:
# C:\Users\VAIBHAV\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\VAIBHAV\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\VAIBHAV\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  diff2   No. Observations:                 5097
# Model:                 ARIMA(3, 2, 1)   Log Likelihood              -23829.905
# Date:                Wed, 20 Sep 2023   AIC                          47669.811
# Time:                        02:49:34   BIC                          47702.491
# Sample:                             0   HQIC                         47681.254
#                                - 5097
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0156      0.007     -2.339      0.019      -0.029      -0.003
# ar.L2         -0.5140      0.001   -446.680      0.000      -0.516      -0.512
# ar.L3          0.0141      0.009      1.605      0.108      -0.003       0.031
# ma.L1         -1.0000      0.056    -17.866      0.000      -1.110      -0.890
# sigma2       673.1405     37.068     18.159      0.000     600.488     745.793
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):          28290514.44
# Prob(Q):                              0.76   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.08   Skew:                            -7.01
# Prob(H) (two-sided):                  0.00   Kurtosis:                       367.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
len=nf1['diff2'].dropna()

# %%
len
# Out:
# Date
# 2000-01-05    -4.50
# 2000-01-06    16.60
# 2000-01-07    12.50
# 2000-01-10   -12.60
# 2000-01-11   -19.00
#               ...
# 2020-06-24    -1.55
# 2020-06-25    -4.40
# 2020-06-26    -0.05
# 2020-06-29     1.60
# 2020-06-30    -1.85
# Name: diff2, Length: 5095, dtype: float64

# %%
train=nf1[:len-1000]
test=nf1[len-1000:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 train=nf1[:len-1000]
#       2 test=nf1[len-1000:]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:3779, in DataFrame.__getitem__(self, key)
#    3777         return self._getitem_multilevel(key)
#    3778 # Do we have a slicer (on rows)?
# -> 3779 indexer = convert_to_index_sliceable(self, key)
#    3780 if indexer is not None:
#    3781     if isinstance(indexer, np.ndarray):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:2494, in convert_to_index_sliceable(obj, key)
#    2492 idx = obj.index
#    2493 if isinstance(key, slice):
# -> 2494     return idx._convert_slice_indexer(key, kind="getitem")
#    2496 elif isinstance(key, str):
#    2497
#    2498     # we are an actual column
#    2499     if key in obj.columns:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4284, in Index._convert_slice_indexer(self, key, kind)
#    4282     indexer = key
#    4283 else:
# -> 4284     indexer = self.slice_indexer(start, stop, step)
#    4286 return indexer
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\datetimes.py:809, in DatetimeIndex.slice_indexer(self, start, end, step, kind)
#     801 # GH#33146 if start and end are combinations of str and None and Index is not
#     802 # monotonic, we can not use Index.slice_indexer because it does not honor the
#     803 # actual elements, is only searching for start and end
#     804 if (
#     805     check_str_or_none(start)
#     806     or check_str_or_none(end)
#     807     or self.is_monotonic_increasing
#     808 ):
# --> 809     return Index.slice_indexer(self, start, end, step, kind=kind)
#     811 mask = np.array(True)
#     812 deprecation_mask = np.array(True)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6559, in Index.slice_indexer(self, start, end, step, kind)
#    6516 """
#    6517 Compute the slice indexer for input labels and step.
#    6518
#    (...)
#    6555 slice(1, 3, None)
#    6556 """
#    6557 self._deprecated_arg(kind, "kind", "slice_indexer")
# -> 6559 start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6561 # return a slice
#    6562 if not is_scalar(start_slice):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6773, in Index.slice_locs(self, start, end, step, kind)
#    6771 end_slice = None
#    6772 if end is not None:
# -> 6773     end_slice = self.get_slice_bound(end, "right")
#    6774 if end_slice is None:
#    6775     end_slice = len(self)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6676, in Index.get_slice_bound(self, label, side, kind)
#    6672 original_label = label
#    6674 # For datetime indices label may be a string that has to be converted
#    6675 # to datetime boundary according to its resolution.
# -> 6676 label = self._maybe_cast_slice_bound(label, side)
#    6678 # we need to look up the label
#    6679 try:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\datetimes.py:767, in DatetimeIndex._maybe_cast_slice_bound(self, label, side, kind)
#     762 if isinstance(label, date) and not isinstance(label, datetime):
#     763     # Pandas supports slicing with dates, treated as datetimes at midnight.
#     764     # https://github.com/pandas-dev/pandas/issues/31501
#     765     label = Timestamp(label).to_pydatetime()
# --> 767 label = super()._maybe_cast_slice_bound(label, side, kind=kind)
#     768 self._deprecate_mismatched_indexing(label)
#     769 return self._maybe_cast_for_get_loc(label)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\datetimelike.py:320, in DatetimeIndexOpsMixin._maybe_cast_slice_bound(self, label, side, kind)
#     318     return lower if side == "left" else upper
#     319 elif not isinstance(label, self._data._recognized_scalars):
# --> 320     raise self._invalid_indexer("slice", label)
#     322 return label
#
# TypeError: cannot do slice indexing on DatetimeIndex with these indexers [Date
# 2000-01-05   -1004.50
# 2000-01-06    -983.40
# 2000-01-07    -987.50
# 2000-01-10   -1012.60
# 2000-01-11   -1019.00
#                ...
# 2020-06-24   -1001.55
# 2020-06-25   -1004.40
# 2020-06-26   -1000.05
# 2020-06-29    -998.40
# 2020-06-30   -1001.85
# Name: diff2, Length: 5095, dtype: float64] of type Series

# %%
#import statsmodels.api as sm

# %%
#model=sm.tsa.statespace.SARIMAX(nf1['diff2'],order=(3,2,1),seasonal_order=(3,2,1,12))
#results=model.fit()

# %%
#nf1['Forecast']=model_fit.predict(start=len(train),end=nf1[nf1['diff2'].dropna()-1000:],dynamic=True)

# %%
#len=len(nf1['diff2'].dropna())

# %%
#len(nf1['diff2'])

# %%
#train=nf1[:len-1000]

# %%
#train.shape

# %%
#test=nf1[len-1000:]

# %%
#test.shape
